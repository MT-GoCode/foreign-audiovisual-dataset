# %%
# %%capture
# !pip install yt-dlp youtube_search_python gspread pydrive2 google-auth #google-auth-oauthlib google-auth-httplib2

# %% [markdown]
# # PARAMETERS

# %%
QUERY_SHEET_ID = "1ZpVOor2FWBvX-bUp7NTX4CyoTRxJj2NclLSlYIRgdtc"
VIDEO_SHEET_ID = "1BBmV1Asb2brp7mzvukwYcG49rZT99iS0t46OCqJDSak"


VIDEO_OUTPUT_PATH = "/content/drive/MyDrive/FLAWLESS_ROOT_DIRECTORY/Data/raw_videos/"

# %% [markdown]
# # SETUP

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Google Sheets - Video Sheet and Search Queries Sheet

# %%
from google.colab import auth
from google.auth import default
import google.auth.transport.requests
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
import gspread
import pandas as pd

class QuerySheet:

  def __init__(self, FILE_ID):
    auth.authenticate_user()
    self.creds, _ = default(scopes=['https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/spreadsheets'])
    gauth = GoogleAuth()
    gauth.credentials = self.creds
    drive = GoogleDrive(gauth)
    self.gc = gspread.authorize(self.creds)

    spreadsheet = self.gc.open_by_key(FILE_ID)
    self.worksheet = spreadsheet.sheet1

    data = self.worksheet.get_all_values()
    headers = data.pop(0)
    self.df = pd.DataFrame(data, columns=headers)

  def get_df(self):
    return self.df

  def mark_query_processed(self, text):
    self.df.loc[self.df['QUERY'] == text, 'PROCESSED?'] = 1

  def get_new_queries(self):
    return self.df[self.df.iloc[:, 1] != "1"].iloc[:, 0].tolist()

  def update_sheet(self):
    self.worksheet.clear()
    data = [self.df.columns.values.tolist()] + self.df.values.tolist()
    self.worksheet.update('A1', data)


class VideoSheet:

  def __init__(self, VIDEO_CSV_ID):
    auth.authenticate_user()
    self.creds, _ = default(scopes=['https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/spreadsheets'])
    gauth = GoogleAuth()
    gauth.credentials = self.creds
    drive = GoogleDrive(gauth)
    self.gc = gspread.authorize(self.creds)

    spreadsheet = self.gc.open_by_key(VIDEO_CSV_ID)
    self.worksheet = spreadsheet.sheet1

    data = self.worksheet.get_all_values()
    headers = data.pop(0)
    self.df = pd.DataFrame(data, columns=headers)

  def add_video_data(self, df):
    next_row = len(self.worksheet.get_all_values()) + 1
    # Convert DataFrame to a list of lists, include header if sheet is completely empty
    if next_row == 1:
        data = [df.columns.values.tolist()] + df.values.tolist()
    else:
        data = df.values.tolist()
    # Update worksheet starting from the next empty row
    self.worksheet.update(f'A{next_row}', data)

  def update_sheet(self):
    self.worksheet.clear()
    data = [self.df.columns.values.tolist()] + self.df.values.tolist()
    self.worksheet.update('A1', data)

# %% [markdown]
# ## Youtube Functions

# %%
import pandas as pd
from youtubesearchpython import VideosSearch
import json

def get_youtube_data(query, results_limit=5):
    video_search = VideosSearch(query, limit=results_limit)
    results = video_search.result()
    return [x['id'] for x in results['result'] ]

    # returns a bunch of ID's

import yt_dlp
import pandas as pd

def get_video_info(url):

    ydl_opts = {
        'skip_download': True,  # Do not download the video
        'force_generic_extractor': True,  # This might be necessary if yt-dlp is unable to download video info directly
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        # Fetch video information
        info_dict = ydl.extract_info(url, download=False)
        # Since '--print-json' is not directly available, we work with the info_dict returned
        print(info_dict)
        return info_dict

def produce_video_record(url):

    # try except to account for video being copyrighted
    try:
        info = get_video_info(url)
        record = pd.Series([info.get('id'), info.get('title', 'N/A'), url, f"{info.get('width', 'N/A')}x{info.get('height', 'N/A')}", info.get('duration', 'N/A'), info.get('language', 'N/A')],
            index = ['VIDEO ID', 'Name', 'Video Link', 'Resolution', 'Duration', 'Language'])
        return record
    except Exception as e:
        print("Could not get video url: ", e)
        return pd.Series(['N/A', 'N/A', url, 'N/A', 'N/A', 'N/A'], index=['VIDEO ID', 'Name', 'Video Link', 'Resolution', 'Duration', 'Language'])



def download_video(video_url, desired_name, output_path):
    ydl_opts = {
        'format': 'best[ext=mp4]',
        'outtmpl': VIDEO_OUTPUT_PATH + desired_name + '.%(ext)s',
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        try:
            ydl.download([video_url])
            print("Video downloaded successfully.")
        except Exception as e:
            print("An error occurred while downloading the video: ", e)

# %% [markdown]
# # Execution

# %%
# testing new loop logic
VS = VideoSheet(VIDEO_SHEET_ID)
QS = QuerySheet(QUERY_SHEET_ID)

VIDEO_ID_QUEUE = []

search_queries = QS.get_new_queries()

for query in search_queries:
    VIDEO_ID_QUEUE += get_youtube_data(query, results_limit = 4)

# %%
len(search_queries)
# Out:
# 3438

# %%
search_queries
# Out:
# ['Godzilla clips',
#  'Godzilla scene',
#  'Godzilla opening',
#  'Godzilla ending',
#  'Godzilla trailer',
#  '哥斯拉 clips',
#  '哥斯拉 scene',
#  '哥斯拉 opening',
#  '哥斯拉 ending',
#  '哥斯拉 trailer',
#  'Годзилла clips',
#  'Годзилла scene',
#  'Годзилла opening',
#  'Годзилла ending',
#  'Годзилла trailer',
#  'Γκοτζίλα clips',
#  'Γκοτζίλα scene',
#  'Γκοτζίλα opening',
#  'Γκοτζίλα ending',
#  'Γκοτζίλα trailer',
#  'גודזילה clips',
#  'גודזילה scene',
#  'גודזילה opening',
#  'גודזילה ending',
#  'גודזילה trailer',
#  'ก็อดซิลล่า clips',
#  'ก็อดซิลล่า scene',
#  'ก็อดซิลล่า opening',
#  'ก็อดซิลล่า ending',
#  'ก็อดซิลล่า trailer',
#  'Godzila clips',
#  'Godzila scene',
#  'Godzila opening',
#  'Godzila ending',
#  'Godzila trailer',
#  'Годзила clips',
#  'Годзила scene',
#  'Годзила opening',
#  'Годзила ending',
#  'Годзила trailer',
#  'GODZILLA ゴジラ clips',
#  'GODZILLA ゴジラ scene',
#  'GODZILLA ゴジラ opening',
#  'GODZILLA ゴジラ ending',
#  'GODZILLA ゴジラ trailer',
#  '고질라 clips',
#  '고질라 scene',
#  '고질라 opening',
#  '고질라 ending',
#  '고질라 trailer',
#  'Ґодзілла clips',
#  'Ґодзілла scene',
#  'Ґодзілла opening',
#  'Ґодзілла ending',
#  'Ґодзілла trailer',
#  '哥吉拉 clips',
#  '哥吉拉 scene',
#  '哥吉拉 opening',
#  '哥吉拉 ending',
#  '哥吉拉 trailer',
#  'गॉडज़िला clips',
#  'गॉडज़िला scene',
#  'गॉडज़िला opening',
#  'गॉडज़िला ending',
#  'गॉडज़िला trailer',
#  'გოძილა clips',
#  'გოძილა scene',
#  'გოძილა opening',
#  'გოძილა ending',
#  'გოძილა trailer',
#  'گودزیلا clips',
#  'گودزیلا scene',
#  'گودزیلا opening',
#  'گودزیلا ending',
#  'گودزیلا trailer',
#  'Interstellar clips',
#  'Interstellar scene',
#  'Interstellar opening',
#  'Interstellar ending',
#  'Interstellar trailer',
#  'clips',
#  'scene',
#  'opening',
#  'ending',
#  'trailer',
#  'Csillagok között clips',
#  'Csillagok között scene',
#  'Csillagok között opening',
#  'Csillagok között ending',
#  'Csillagok között trailer',
#  'Интерстеллар clips',
#  'Интерстеллар scene',
#  'Интерстеллар opening',
#  'Интерстеллар ending',
#  'Интерстеллар trailer',
#  '星际穿越 clips',
#  '星际穿越 scene',
#  '星际穿越 opening',
#  '星际穿越 ending',
#  '星际穿越 trailer',
#  'בין כוכבים clips',
#  'בין כוכבים scene',
#  'בין כוכבים opening',
#  'בין כוכבים ending',
#  'בין כוכבים trailer',
#  'Интерстелар clips',
#  'Интерстелар scene',
#  'Интерстелар opening',
#  'Интерстелар ending',
#  'Интерстелар trailer',
#  'Інтерстеллар clips',
#  'Інтерстеллар scene',
#  'Інтерстеллар opening',
#  'Інтерстеллар ending',
#  'Інтерстеллар trailer',
#  'Yıldızlararası clips',
#  'Yıldızlararası scene',
#  'Yıldızlararası opening',
#  'Yıldızlararası ending',
#  'Yıldızlararası trailer',
#  '인터스텔라 clips',
#  '인터스텔라 scene',
#  '인터스텔라 opening',
#  '인터스텔라 ending',
#  '인터스텔라 trailer',
#  'インターステラー clips',
#  'インターステラー scene',
#  'インターステラー opening',
#  'インターステラー ending',
#  'インターステラー trailer',
#  'میان\u200cستاره\u200cای clips',
#  'میان\u200cستاره\u200cای scene',
#  'میان\u200cستاره\u200cای opening',
#  'میان\u200cستاره\u200cای ending',
#  'میان\u200cستاره\u200cای trailer',
#  'Interstellar: Călătorind prin univers clips',
#  'Interstellar: Călătorind prin univers scene',
#  'Interstellar: Călătorind prin univers opening',
#  'Interstellar: Călătorind prin univers ending',
#  'Interstellar: Călătorind prin univers trailer',
#  'ვარსკვლავთშორის clips',
#  'ვარსკვლავთშორის scene',
#  'ვარსკვლავთშორის opening',
#  'ვარსკვლავთშორის ending',
#  'ვარსკვლავთშორის trailer',
#  'อินเตอร์สเตลลาร์ ทะยานดาวกู้โลก clips',
#  'อินเตอร์สเตลลาร์ ทะยานดาวกู้โลก scene',
#  'อินเตอร์สเตลลาร์ ทะยานดาวกู้โลก opening',
#  'อินเตอร์สเตลลาร์ ทะยานดาวกู้โลก ending',
#  'อินเตอร์สเตลลาร์ ทะยานดาวกู้โลก trailer',
#  'Medzvezdje clips',
#  'Medzvezdje scene',
#  'Medzvezdje opening',
#  'Medzvezdje ending',
#  'Medzvezdje trailer',
#  'بين النجوم clips',
#  'بين النجوم scene',
#  'بين النجوم opening',
#  'بين النجوم ending',
#  'بين النجوم trailer',
#  '星際效應 clips',
#  '星際效應 scene',
#  '星際效應 opening',
#  '星際效應 ending',
#  '星際效應 trailer',
#  'Interestelar clips',
#  'Interestelar scene',
#  'Interestelar opening',
#  'Interestelar ending',
#  'Interestelar trailer',
#  'Ulduzlararasi clips',
#  'Ulduzlararasi scene',
#  'Ulduzlararasi opening',
#  'Ulduzlararasi ending',
#  'Ulduzlararasi trailer',
#  'Interstellaire clips',
#  'Interstellaire scene',
#  'Interstellaire opening',
#  'Interstellaire ending',
#  'Interstellaire trailer',
#  'Tähtedevaheline clips',
#  'Tähtedevaheline scene',
#  'Tähtedevaheline opening',
#  'Tähtedevaheline ending',
#  'Tähtedevaheline trailer',
#  'Tarp žvaigždžių clips',
#  'Tarp žvaigždžių scene',
#  'Tarp žvaigždžių opening',
#  'Tarp žvaigždžių ending',
#  'Tarp žvaigždžių trailer',
#  'Hố Đen Tử Thần clips',
#  'Hố Đen Tử Thần scene',
#  'Hố Đen Tử Thần opening',
#  'Hố Đen Tử Thần ending',
#  'Hố Đen Tử Thần trailer',
#  'Међузвездани clips',
#  'Међузвездани scene',
#  'Међузвездани opening',
#  'Међузвездани ending',
#  'Међузвездани trailer',
#  '星際啟示錄 clips',
#  '星際啟示錄 scene',
#  '星際啟示錄 opening',
#  '星際啟示錄 ending',
#  '星際啟示錄 trailer',
#  'Starp zvaigznēm clips',
#  'Starp zvaigznēm scene',
#  'Starp zvaigznēm opening',
#  'Starp zvaigznēm ending',
#  'Starp zvaigznēm trailer',
#  'Інтэрстэлар clips',
#  'Інтэрстэлар scene',
#  'Інтэрстэлар opening',
#  'Інтэрстэлар ending',
#  'Інтэрстэлар trailer',
#  'Dawn of the Planet of the Apes clips',
#  'Dawn of the Planet of the Apes scene',
#  'Dawn of the Planet of the Apes opening',
#  'Dawn of the Planet of the Apes ending',
#  'Dawn of the Planet of the Apes trailer',
#  'clips',
#  'scene',
#  'opening',
#  'ending',
#  'trailer',
#  'Apes Revolution - Il pianeta delle scimmie clips',
#  'Apes Revolution - Il pianeta delle scimmie scene',
#  'Apes Revolution - Il pianeta delle scimmie opening',
#  'Apes Revolution - Il pianeta delle scimmie ending',
#  'Apes Revolution - Il pianeta delle scimmie trailer',
#  "La Planète des singes : L'Affrontement clips",
#  "La Planète des singes : L'Affrontement scene",
#  "La Planète des singes : L'Affrontement opening",
#  "La Planète des singes : L'Affrontement ending",
#  "La Planète des singes : L'Affrontement trailer",
#  'Planet der Affen - Revolution clips',
#  'Planet der Affen - Revolution scene',
#  'Planet der Affen - Revolution opening',
#  'Planet der Affen - Revolution ending',
#  'Planet der Affen - Revolution trailer',
#  'El amanecer del planeta de los simios clips',
#  'El amanecer del planeta de los simios scene',
#  'El amanecer del planeta de los simios opening',
#  'El amanecer del planeta de los simios ending',
#  'El amanecer del planeta de los simios trailer',
#  'Ewolucja Planety Małp clips',
#  'Ewolucja Planety Małp scene',
#  'Ewolucja Planety Małp opening',
#  'Ewolucja Planety Małp ending',
#  'Ewolucja Planety Małp trailer',
#  'Планета обезьян: Революция clips',
#  'Планета обезьян: Революция scene',
#  'Планета обезьян: Революция opening',
#  'Планета обезьян: Революция ending',
#  'Планета обезьян: Революция trailer',
#  'Planeta dos Macacos: A Revolta clips',
#  'Planeta dos Macacos: A Revolta scene',
#  'Planeta dos Macacos: A Revolta opening',
#  'Planeta dos Macacos: A Revolta ending',
#  'Planeta dos Macacos: A Revolta trailer',
#  'Зората на планетата на маймуните clips',
#  'Зората на планетата на маймуните scene',
#  'Зората на планетата на маймуните opening',
#  'Зората на планетата на маймуните ending',
#  'Зората на планетата на маймуните trailer',
#  'Apornas planet: Uppgörelsen clips',
#  'Apornas planet: Uppgörelsen scene',
#  'Apornas planet: Uppgörelsen opening',
#  'Apornas planet: Uppgörelsen ending',
#  'Apornas planet: Uppgörelsen trailer',
#  'A majmok bolygója: Forradalom clips',
#  'A majmok bolygója: Forradalom scene',
#  'A majmok bolygója: Forradalom opening',
#  'A majmok bolygója: Forradalom ending',
#  'A majmok bolygója: Forradalom trailer',
#  'Úsvit planéty opíc clips',
#  'Úsvit planéty opíc scene',
#  'Úsvit planéty opíc opening',
#  'Úsvit planéty opíc ending',
#  'Úsvit planéty opíc trailer',
#  'Úsvit planety opic clips',
#  'Úsvit planety opic scene',
#  'Úsvit planety opic opening',
#  'Úsvit planety opic ending',
#  'Úsvit planety opic trailer',
#  '혹성탈출: 반격의 서막 clips',
#  '혹성탈출: 반격의 서막 scene',
#  '혹성탈출: 반격의 서막 opening',
#  '혹성탈출: 반격의 서막 ending',
#  '혹성탈출: 반격의 서막 trailer',
#  '猩球崛起2：黎明之战 clips',
#  '猩球崛起2：黎明之战 scene',
#  '猩球崛起2：黎明之战 opening',
#  '猩球崛起2：黎明之战 ending',
#  '猩球崛起2：黎明之战 trailer',
#  'รุ่งอรุณแห่งอาณาจักรพิภพวานร clips',
#  'รุ่งอรุณแห่งอาณาจักรพิภพวานร scene',
#  'รุ่งอรุณแห่งอาณาจักรพิภพวานร opening',
#  'รุ่งอรุณแห่งอาณาจักรพิภพวานร ending',
#  'รุ่งอรุณแห่งอาณาจักรพิภพวานร trailer',
#  'Maymunlar Cehennemi: Şafak Vakti clips',
#  'Maymunlar Cehennemi: Şafak Vakti scene',
#  'Maymunlar Cehennemi: Şafak Vakti opening',
#  'Maymunlar Cehennemi: Şafak Vakti ending',
#  'Maymunlar Cehennemi: Şafak Vakti trailer',
#  'Apinoiden planeetan vallankumous clips',
#  'Apinoiden planeetan vallankumous scene',
#  'Apinoiden planeetan vallankumous opening',
#  'Apinoiden planeetan vallankumous ending',
#  'Apinoiden planeetan vallankumous trailer',
#  'כוכב הקופים: השחר clips',
#  'כוכב הקופים: השחר scene',
#  'כוכב הקופים: השחר opening',
#  'כוכב הקופים: השחר ending',
#  'כוכב הקופים: השחר trailer',
#  'Ο Πλανήτης των Πιθήκων: Η Αυγή clips',
#  'Ο Πλανήτης των Πιθήκων: Η Αυγή scene',
#  'Ο Πλανήτης των Πιθήκων: Η Αυγή opening',
#  'Ο Πλανήτης των Πιθήκων: Η Αυγή ending',
#  'Ο Πλανήτης των Πιθήκων: Η Αυγή trailer',
#  'Abernes planet: Revolutionen clips',
#  'Abernes planet: Revolutionen scene',
#  'Abernes planet: Revolutionen opening',
#  'Abernes planet: Revolutionen ending',
#  'Abernes planet: Revolutionen trailer',
#  'Світанок планети мавп clips',
#  'Світанок планети мавп scene',
#  'Світанок планети мавп opening',
#  'Світанок планети мавп ending',
#  'Світанок планети мавп trailer',
#  'Planeta Maimuțelor: Revoluție clips',
#  'Planeta Maimuțelor: Revoluție scene',
#  'Planeta Maimuțelor: Revoluție opening',
#  'Planeta Maimuțelor: Revoluție ending',
#  'Planeta Maimuțelor: Revoluție trailer',
#  '猿の惑星：新世紀（ライジング） clips',
#  '猿の惑星：新世紀（ライジング） scene',
#  '猿の惑星：新世紀（ライジング） opening',
#  '猿の惑星：新世紀（ライジング） ending',
#  '猿の惑星：新世紀（ライジング） trailer',
#  'Planeta dos Macacos: O Confronto clips',
#  'Planeta dos Macacos: O Confronto scene',
#  'Planeta dos Macacos: O Confronto opening',
#  'Planeta dos Macacos: O Confronto ending',
#  'Planeta dos Macacos: O Confronto trailer',
#  '猩球崛起：黎明的進擊 clips',
#  '猩球崛起：黎明的進擊 scene',
#  '猩球崛起：黎明的進擊 opening',
#  '猩球崛起：黎明的進擊 ending',
#  '猩球崛起：黎明的進擊 trailer',
#  'طلوع سیاره میمون\u200cها clips',
#  'طلوع سیاره میمون\u200cها scene',
#  'طلوع سیاره میمون\u200cها opening',
#  'طلوع سیاره میمون\u200cها ending',
#  'طلوع سیاره میمون\u200cها trailer',
#  "L'Aube de la planète des singes clips",
#  "L'Aube de la planète des singes scene",
#  "L'Aube de la planète des singes opening",
#  "L'Aube de la planète des singes ending",
#  "L'Aube de la planète des singes trailer",
#  'Планета мајмуна: Револуција clips',
#  'Планета мајмуна: Револуција scene',
#  'Планета мајмуна: Револуција opening',
#  'Планета мајмуна: Револуција ending',
#  'Планета мајмуна: Револуција trailer',
#  'El Planeta de los Simios: Confrontación clips',
#  'El Planeta de los Simios: Confrontación scene',
#  'El Planeta de los Simios: Confrontación opening',
#  'El Planeta de los Simios: Confrontación ending',
#  'El Planeta de los Simios: Confrontación trailer',
#  'Pērtiķu planētas atmoda clips',
#  'Pērtiķu planētas atmoda scene',
#  'Pērtiķu planētas atmoda opening',
#  'Pērtiķu planētas atmoda ending',
#  'Pērtiķu planētas atmoda trailer',
#  'Tagiĝo de la planedo de la homsimioj clips',
#  'Tagiĝo de la planedo de la homsimioj scene',
#  'Tagiĝo de la planedo de la homsimioj opening',
#  'Tagiĝo de la planedo de la homsimioj ending',
#  'Tagiĝo de la planedo de la homsimioj trailer',
#  'Beždžionių planetos aušra clips',
#  'Beždžionių planetos aušra scene',
#  'Beždžionių planetos aušra opening',
#  'Beždžionių planetos aušra ending',
#  'Beždžionių planetos aušra trailer',
#  '猿人爭霸戰：猩凶崛起 clips',
#  '猿人爭霸戰：猩凶崛起 scene',
#  '猿人爭霸戰：猩凶崛起 opening',
#  '猿人爭霸戰：猩凶崛起 ending',
#  '猿人爭霸戰：猩凶崛起 trailer',
#  'Planet majmuna: Revolucija clips',
#  'Planet majmuna: Revolucija scene',
#  'Planet majmuna: Revolucija opening',
#  'Planet majmuna: Revolucija ending',
#  'Planet majmuna: Revolucija trailer',
#  'Zora Planeta opic clips',
#  'Zora Planeta opic scene',
#  'Zora Planeta opic opening',
#  'Zora Planeta opic ending',
#  'Zora Planeta opic trailer',
#  'Sự Khởi Đầu Của Hành Tinh Khỉ clips',
#  'Sự Khởi Đầu Của Hành Tinh Khỉ scene',
#  'Sự Khởi Đầu Của Hành Tinh Khỉ opening',
#  'Sự Khởi Đầu Của Hành Tinh Khỉ ending',
#  'Sự Khởi Đầu Của Hành Tinh Khỉ trailer',
#  'فجر كوكب القردة clips',
#  'فجر كوكب القردة scene',
#  'فجر كوكب القردة opening',
#  'فجر كوكب القردة ending',
#  'فجر كوكب القردة trailer',
#  'მაიმუნების პლანეტა რევოლუცია clips',
#  'მაიმუნების პლანეტა რევოლუცია scene',
#  'მაიმუნების პლანეტა რევოლუცია opening',
#  'მაიმუნების პლანეტა რევოლუცია ending',
#  'მაიმუნების პლანეტა რევოლუცია trailer',
#  "L'alba del planeta dels simis clips",
#  "L'alba del planeta dels simis scene",
#  "L'alba del planeta dels simis opening",
#  "L'alba del planeta dels simis ending",
#  "L'alba del planeta dels simis trailer",
#  'The Maze Runner clips',
#  'The Maze Runner scene',
#  'The Maze Runner opening',
#  'The Maze Runner ending',
#  'The Maze Runner trailer',
#  'clips',
#  'scene',
#  'opening',
#  'ending',
#  'trailer',
#  'Maze Runner - Die Auserwählten im Labyrinth clips',
#  'Maze Runner - Die Auserwählten im Labyrinth scene',
#  'Maze Runner - Die Auserwählten im Labyrinth opening',
#  'Maze Runner - Die Auserwählten im Labyrinth ending',
#  'Maze Runner - Die Auserwählten im Labyrinth trailer',
#  'El corredor del laberinto clips',
#  'El corredor del laberinto scene',
#  'El corredor del laberinto opening',
#  'El corredor del laberinto ending',
#  'El corredor del laberinto trailer',
#  'Бегущий в лабиринте clips',
#  'Бегущий в лабиринте scene',
#  'Бегущий в лабиринте opening',
#  'Бегущий в лабиринте ending',
#  'Бегущий в лабиринте trailer',
#  'Le Labyrinthe clips',
#  'Le Labyrinthe scene',
#  'Le Labyrinthe opening',
#  'Le Labyrinthe ending',
#  'Le Labyrinthe trailer',
#  'Maze Runner - Il labirinto clips',
#  'Maze Runner - Il labirinto scene',
#  'Maze Runner - Il labirinto opening',
#  'Maze Runner - Il labirinto ending',
#  'Maze Runner - Il labirinto trailer',
#  'Labyrint: Útěk clips',
#  'Labyrint: Útěk scene',
#  'Labyrint: Útěk opening',
#  'Labyrint: Útěk ending',
#  'Labyrint: Útěk trailer',
#  'Więzień labiryntu clips',
#  'Więzień labiryntu scene',
#  'Więzień labiryntu opening',
#  'Więzień labiryntu ending',
#  'Więzień labiryntu trailer',
#  'Az útvesztő clips',
#  'Az útvesztő scene',
#  'Az útvesztő opening',
#  'Az útvesztő ending',
#  'Az útvesztő trailer',
#  'เมซ รันเนอร์ : วงกตมฤตยู clips',
#  'เมซ รันเนอร์ : วงกตมฤตยู scene',
#  'เมซ รันเนอร์ : วงกตมฤตยู opening',
#  'เมซ รันเนอร์ : วงกตมฤตยู ending',
#  'เมซ รันเนอร์ : วงกตมฤตยู trailer',
#  'Ο Λαβύρινθος clips',
#  'Ο Λαβύρινθος scene',
#  'Ο Λαβύρινθος opening',
#  'Ο Λαβύρινθος ending',
#  'Ο Λαβύρινθος trailer',
#  'Labirent: Ölümcül Kaçış clips',
#  'Labirent: Ölümcül Kaçış scene',
#  'Labirent: Ölümcül Kaçış opening',
#  'Labirent: Ölümcül Kaçış ending',
#  'Labirent: Ölümcül Kaçış trailer',
#  'Maze Runner - Correr ou Morrer clips',
#  'Maze Runner - Correr ou Morrer scene',
#  'Maze Runner - Correr ou Morrer opening',
#  'Maze Runner - Correr ou Morrer ending',
#  'Maze Runner - Correr ou Morrer trailer',
#  '移动迷宫 clips',
#  '移动迷宫 scene',
#  '移动迷宫 opening',
#  '移动迷宫 ending',
#  '移动迷宫 trailer',
#  'Labyrint: Útek clips',
#  'Labyrint: Útek scene',
#  'Labyrint: Útek opening',
#  'Labyrint: Útek ending',
#  'Labyrint: Útek trailer',
#  'הרץ במבוך clips',
#  'הרץ במבוך scene',
#  'הרץ במבוך opening',
#  'הרץ במבוך ending',
#  'הרץ במבוך trailer',
#  'Лабиринтът: Невъзможно бягство clips',
#  'Лабиринтът: Невъзможно бягство scene',
#  'Лабиринтът: Невъзможно бягство opening',
#  'Лабиринтът: Невъзможно бягство ending',
#  'Лабиринтът: Невъзможно бягство trailer',
#  'Labyrintti clips',
#  'Labyrintti scene',
#  'Labyrintti opening',
#  'Labyrintti ending',
#  'Labyrintti trailer',
#  '메이즈 러너 clips',
#  '메이즈 러너 scene',
#  '메이즈 러너 opening',
#  '메이즈 러너 ending',
#  '메이즈 러너 trailer',
#  'Labirint: Nemogući bijeg clips',
#  'Labirint: Nemogući bijeg scene',
#  'Labirint: Nemogući bijeg opening',
#  'Labirint: Nemogući bijeg ending',
#  'Labirint: Nemogući bijeg trailer',
#  'Labirintu skrējējs clips',
#  'Labirintu skrējējs scene',
#  'Labirintu skrējējs opening',
#  'Labirintu skrējējs ending',
#  'Labirintu skrējējs trailer',
#  'Той, що біжить лабіринтом clips',
#  'Той, що біжить лабіринтом scene',
#  'Той, що біжить лабіринтом opening',
#  'Той, що біжить лабіринтом ending',
#  'Той, що біжить лабіринтом trailer',
#  'متسابق المتاهة clips',
#  'متسابق المتاهة scene',
#  'متسابق المتاهة opening',
#  'متسابق المتاهة ending',
#  'متسابق المتاهة trailer',
#  'Labirintul: Evadarea clips',
#  'Labirintul: Evadarea scene',
#  'Labirintul: Evadarea opening',
#  'Labirintul: Evadarea ending',
#  'Labirintul: Evadarea trailer',
#  'Bėgantis labirintu clips',
#  'Bėgantis labirintu scene',
#  'Bėgantis labirintu opening',
#  'Bėgantis labirintu ending',
#  'Bėgantis labirintu trailer',
#  'メイズ・ランナー clips',
#  'メイズ・ランナー scene',
#  'メイズ・ランナー opening',
#  'メイズ・ランナー ending',
#  'メイズ・ランナー trailer',
#  'Maze Runner: Correr ou Morrer clips',
#  'Maze Runner: Correr ou Morrer scene',
#  'Maze Runner: Correr ou Morrer opening',
#  'Maze Runner: Correr ou Morrer ending',
#  'Maze Runner: Correr ou Morrer trailer',
#  'Labirint clips',
#  'Labirint scene',
#  'Labirint opening',
#  'Labirint ending',
#  'Labirint trailer',
#  "L'épreuve : Le labyrinthe clips",
#  "L'épreuve : Le labyrinthe scene",
#  "L'épreuve : Le labyrinthe opening",
#  "L'épreuve : Le labyrinthe ending",
#  "L'épreuve : Le labyrinthe trailer",
#  '移動迷宮 clips',
#  '移動迷宮 scene',
#  '移動迷宮 opening',
#  '移動迷宮 ending',
#  '移動迷宮 trailer',
#  'Лавиринт: Немогуће бекство clips',
#  'Лавиринт: Немогуће бекство scene',
#  'Лавиринт: Немогуће бекство opening',
#  'Лавиринт: Немогуће бекство ending',
#  'Лавиринт: Немогуће бекство trailer',
#  'دونده مارپیچ clips',
#  'دونده مارپیچ scene',
#  'دونده مارپیچ opening',
#  'دونده مارپیچ ending',
#  'دونده مارپیچ trailer',
#  'Maze Runner: Correr o morir clips',
#  'Maze Runner: Correr o morir scene',
#  'Maze Runner: Correr o morir opening',
#  'Maze Runner: Correr o morir ending',
#  'Maze Runner: Correr o morir trailer',
#  'Беглы ў лабірынце clips',
#  'Беглы ў лабірынце scene',
#  'Беглы ў лабірынце opening',
#  'Беглы ў лабірынце ending',
#  'Беглы ў лабірынце trailer',
#  'The Maze Runner - I dødens labyrint clips',
#  'The Maze Runner - I dødens labyrint scene',
#  'The Maze Runner - I dødens labyrint opening',
#  'The Maze Runner - I dødens labyrint ending',
#  'The Maze Runner - I dødens labyrint trailer',
#  'Giải Mã Mê Cung clips',
#  'Giải Mã Mê Cung scene',
#  'Giải Mã Mê Cung opening',
#  'Giải Mã Mê Cung ending',
#  'Giải Mã Mê Cung trailer',
#  'ლაბირინთში მორბენალი clips',
#  'ლაბირინთში მორბენალი scene',
#  'ლაბირინთში მორბენალი opening',
#  'ლაბირინთში მორბენალი ending',
#  'ლაბირინთში მორბენალი trailer',
#  'El corredor del laberint clips',
#  'El corredor del laberint scene',
#  'El corredor del laberint opening',
#  'El corredor del laberint ending',
#  'El corredor del laberint trailer',
#  'The Hobbit: The Battle of the Five Armies clips',
#  'The Hobbit: The Battle of the Five Armies scene',
#  'The Hobbit: The Battle of the Five Armies opening',
#  'The Hobbit: The Battle of the Five Armies ending',
#  'The Hobbit: The Battle of the Five Armies trailer',
#  'clips',
#  'scene',
#  'opening',
#  'ending',
#  'trailer',
#  '霍比特人3：五军之战 clips',
#  '霍比特人3：五军之战 scene',
#  '霍比特人3：五军之战 opening',
#  '霍比特人3：五军之战 ending',
#  '霍比特人3：五军之战 trailer',
#  'Le Hobbit : La Bataille des cinq armées clips',
#  'Le Hobbit : La Bataille des cinq armées scene',
#  'Le Hobbit : La Bataille des cinq armées opening',
#  'Le Hobbit : La Bataille des cinq armées ending',
#  'Le Hobbit : La Bataille des cinq armées trailer',
#  'El hobbit: La batalla de los cinco ejércitos clips',
#  'El hobbit: La batalla de los cinco ejércitos scene',
#  'El hobbit: La batalla de los cinco ejércitos opening',
#  'El hobbit: La batalla de los cinco ejércitos ending',
#  'El hobbit: La batalla de los cinco ejércitos trailer',
#  'A hobbit: Az öt sereg csatája clips',
#  'A hobbit: Az öt sereg csatája scene',
#  'A hobbit: Az öt sereg csatája opening',
#  'A hobbit: Az öt sereg csatája ending',
#  'A hobbit: Az öt sereg csatája trailer',
#  'Lo Hobbit: La battaglia delle cinque armate clips',
#  'Lo Hobbit: La battaglia delle cinque armate scene',
#  'Lo Hobbit: La battaglia delle cinque armate opening',
#  'Lo Hobbit: La battaglia delle cinque armate ending',
#  'Lo Hobbit: La battaglia delle cinque armate trailer',
#  'Der Hobbit - Die Schlacht der fünf Heere clips',
#  'Der Hobbit - Die Schlacht der fünf Heere scene',
#  'Der Hobbit - Die Schlacht der fünf Heere opening',
#  'Der Hobbit - Die Schlacht der fünf Heere ending',
#  'Der Hobbit - Die Schlacht der fünf Heere trailer',
#  'O Hobbit: A Batalha dos Cinco Exércitos clips',
#  'O Hobbit: A Batalha dos Cinco Exércitos scene',
#  'O Hobbit: A Batalha dos Cinco Exércitos opening',
#  'O Hobbit: A Batalha dos Cinco Exércitos ending',
#  'O Hobbit: A Batalha dos Cinco Exércitos trailer',
#  'Hobit: Bitva pěti armád clips',
#  'Hobit: Bitva pěti armád scene',
#  'Hobit: Bitva pěti armád opening',
#  'Hobit: Bitva pěti armád ending',
#  'Hobit: Bitva pěti armád trailer',
#  'Хоббит: Битва пяти воинств clips',
#  'Хоббит: Битва пяти воинств scene',
#  'Хоббит: Битва пяти воинств opening',
#  'Хоббит: Битва пяти воинств ending',
#  'Хоббит: Битва пяти воинств trailer',
#  'Hobit: Bitka piatich armád clips',
#  'Hobit: Bitka piatich armád scene',
#  'Hobit: Bitka piatich armád opening',
#  'Hobit: Bitka piatich armád ending',
#  'Hobit: Bitka piatich armád trailer',
#  'ההוביט: קרב חמשת הצבאות clips',
#  'ההוביט: קרב חמשת הצבאות scene',
#  'ההוביט: קרב חמשת הצבאות opening',
#  'ההוביט: קרב חמשת הצבאות ending',
#  'ההוביט: קרב חמשת הצבאות trailer',
#  'Hobbit: Bitwa Pięciu Armii clips',
#  'Hobbit: Bitwa Pięciu Armii scene',
#  'Hobbit: Bitwa Pięciu Armii opening',
#  'Hobbit: Bitwa Pięciu Armii ending',
#  'Hobbit: Bitwa Pięciu Armii trailer',
#  'Хобит: Битката на петте армии clips',
#  'Хобит: Битката на петте армии scene',
#  'Хобит: Битката на петте армии opening',
#  'Хобит: Битката на петте армии ending',
#  'Хобит: Битката на петте армии trailer',
#  'Hobitti – Viiden armeijan taistelu clips',
#  'Hobitti – Viiden armeijan taistelu scene',
#  'Hobitti – Viiden armeijan taistelu opening',
#  'Hobitti – Viiden armeijan taistelu ending',
#  'Hobitti – Viiden armeijan taistelu trailer',
#  'Χόμπιτ: Η Μάχη των Πέντε Στρατών clips',
#  'Χόμπιτ: Η Μάχη των Πέντε Στρατών scene',
#  'Χόμπιτ: Η Μάχη των Πέντε Στρατών opening',
#  'Χόμπιτ: Η Μάχη των Πέντε Στρατών ending',
#  'Χόμπιτ: Η Μάχη των Πέντε Στρατών trailer',
#  'Hobbit: Beş Ordunun Savaşı clips',
#  'Hobbit: Beş Ordunun Savaşı scene',
#  'Hobbit: Beş Ordunun Savaşı opening',
#  'Hobbit: Beş Ordunun Savaşı ending',
#  'Hobbit: Beş Ordunun Savaşı trailer',
#  'Hobbitten: Femhæreslaget clips',
#  'Hobbitten: Femhæreslaget scene',
#  'Hobbitten: Femhæreslaget opening',
#  'Hobbitten: Femhæreslaget ending',
#  'Hobbitten: Femhæreslaget trailer',
#  'الهوبيت: معركة الجيوش الخمسة clips',
#  'الهوبيت: معركة الجيوش الخمسة scene',
#  'الهوبيت: معركة الجيوش الخمسة opening',
#  'الهوبيت: معركة الجيوش الخمسة ending',
#  'الهوبيت: معركة الجيوش الخمسة trailer',
#  'Hobbit: Femhäraslaget clips',
#  'Hobbit: Femhäraslaget scene',
#  'Hobbit: Femhäraslaget opening',
#  'Hobbit: Femhäraslaget ending',
#  'Hobbit: Femhäraslaget trailer',
#  '호빗: 다섯 군대 전투 clips',
#  '호빗: 다섯 군대 전투 scene',
#  '호빗: 다섯 군대 전투 opening',
#  '호빗: 다섯 군대 전투 ending',
#  '호빗: 다섯 군대 전투 trailer',
#  'เดอะ ฮอบบิท: สงครามห้าทัพ clips',
#  'เดอะ ฮอบบิท: สงครามห้าทัพ scene',
#  'เดอะ ฮอบบิท: สงครามห้าทัพ opening',
#  'เดอะ ฮอบบิท: สงครามห้าทัพ ending',
#  'เดอะ ฮอบบิท: สงครามห้าทัพ trailer',
#  'هابیت: نبرد پنج سپاه clips',
#  'هابیت: نبرد پنج سپاه scene',
#  'هابیت: نبرد پنج سپاه opening',
#  'هابیت: نبرد پنج سپاه ending',
#  'هابیت: نبرد پنج سپاه trailer',
#  'Hobbitul: Bătălia celor cinci oștiri clips',
#  'Hobbitul: Bătălia celor cinci oștiri scene',
#  'Hobbitul: Bătălia celor cinci oștiri opening',
#  'Hobbitul: Bătălia celor cinci oștiri ending',
#  'Hobbitul: Bătălia celor cinci oștiri trailer',
#  'Гобiт: Битва п’яти воїнств clips',
#  'Гобiт: Битва п’яти воїнств scene',
#  'Гобiт: Битва п’яти воїнств opening',
#  'Гобiт: Битва п’яти воїнств ending',
#  'Гобiт: Битва п’яти воїнств trailer',
#  'Hobbiten: Femhærerslaget clips',
#  'Hobbiten: Femhærerslaget scene',
#  'Hobbiten: Femhærerslaget opening',
#  'Hobbiten: Femhærerslaget ending',
#  'Hobbiten: Femhærerslaget trailer',
#  'Hobitas: Penkių armijų mūšis clips',
#  'Hobitas: Penkių armijų mūšis scene',
#  'Hobitas: Penkių armijų mūšis opening',
#  'Hobitas: Penkių armijų mūšis ending',
#  'Hobitas: Penkių armijų mūšis trailer',
#  'Hobbit: Besh Ordunun Döyüshü clips',
#  'Hobbit: Besh Ordunun Döyüshü scene',
#  'Hobbit: Besh Ordunun Döyüshü opening',
#  'Hobbit: Besh Ordunun Döyüshü ending',
#  'Hobbit: Besh Ordunun Döyüshü trailer',
#  'Hobit: Bitka pet vojski clips',
#  'Hobit: Bitka pet vojski scene',
#  'Hobit: Bitka pet vojski opening',
#  'Hobit: Bitka pet vojski ending',
#  'Hobit: Bitka pet vojski trailer',
#  'Hobits: Piecu armiju kauja clips',
#  'Hobits: Piecu armiju kauja scene',
#  'Hobits: Piecu armiju kauja opening',
#  'Hobits: Piecu armiju kauja ending',
#  'Hobits: Piecu armiju kauja trailer',
#  'Хобит: Битка пет армија clips',
#  'Хобит: Битка пет армија scene',
#  'Хобит: Битка пет армија opening',
#  'Хобит: Битка пет армија ending',
#  'Хобит: Битка пет армија trailer',
#  'Hobit: Bitka petih vojska clips',
#  'Hobit: Bitka petih vojska scene',
#  'Hobit: Bitka petih vojska opening',
#  'Hobit: Bitka petih vojska ending',
#  'Hobit: Bitka petih vojska trailer',
#  'ホビット 決戦のゆくえ clips',
#  'ホビット 決戦のゆくえ scene',
#  'ホビット 決戦のゆくえ opening',
#  'ホビット 決戦のゆくえ ending',
#  'ホビット 決戦のゆくえ trailer',
#  '哈比人：五軍之戰 clips',
#  '哈比人：五軍之戰 scene',
#  '哈比人：五軍之戰 opening',
#  '哈比人：五軍之戰 ending',
#  '哈比人：五軍之戰 trailer',
#  'El Hobbit 3: La Batalla de Los Cinco Ejércitos clips',
#  'El Hobbit 3: La Batalla de Los Cinco Ejércitos scene',
#  'El Hobbit 3: La Batalla de Los Cinco Ejércitos opening',
#  'El Hobbit 3: La Batalla de Los Cinco Ejércitos ending',
#  'El Hobbit 3: La Batalla de Los Cinco Ejércitos trailer',
#  'Le Hobbit : La bataille des cinq armées clips',
#  'Le Hobbit : La bataille des cinq armées scene',
#  'Le Hobbit : La bataille des cinq armées opening',
#  'Le Hobbit : La bataille des cinq armées ending',
#  'Le Hobbit : La bataille des cinq armées trailer',
#  'La Hobito: La Batalo de la Kvin Armeoj clips',
#  'La Hobito: La Batalo de la Kvin Armeoj scene',
#  'La Hobito: La Batalo de la Kvin Armeoj opening',
#  'La Hobito: La Batalo de la Kvin Armeoj ending',
#  'La Hobito: La Batalo de la Kvin Armeoj trailer',
#  'Người Hobbit: Đại Chiến Năm Cánh Quân clips',
#  'Người Hobbit: Đại Chiến Năm Cánh Quân scene',
#  'Người Hobbit: Đại Chiến Năm Cánh Quân opening',
#  'Người Hobbit: Đại Chiến Năm Cánh Quân ending',
#  'Người Hobbit: Đại Chiến Năm Cánh Quân trailer',
#  'ჰობიტი: ხუთი არმიის ბრძოლა clips',
#  'ჰობიტი: ხუთი არმიის ბრძოლა scene',
#  'ჰობიტი: ხუთი არმიის ბრძოლა opening',
#  'ჰობიტი: ხუთი არმიის ბრძოლა ending',
#  'ჰობიტი: ხუთი არმიის ბრძოლა trailer',
#  'Der Hobbit: Die Schlacht der fünf Heere clips',
#  'Der Hobbit: Die Schlacht der fünf Heere scene',
#  'Der Hobbit: Die Schlacht der fünf Heere opening',
#  'Der Hobbit: Die Schlacht der fünf Heere ending',
#  'Der Hobbit: Die Schlacht der fünf Heere trailer',
#  'El hòbbit: La batalla dels cinc exèrcits clips',
#  'El hòbbit: La batalla dels cinc exèrcits scene',
#  'El hòbbit: La batalla dels cinc exèrcits opening',
#  'El hòbbit: La batalla dels cinc exèrcits ending',
#  'El hòbbit: La batalla dels cinc exèrcits trailer',
#  'Kääbik: Viie väe lahing clips',
#  'Kääbik: Viie väe lahing scene',
#  'Kääbik: Viie väe lahing opening',
#  'Kääbik: Viie väe lahing ending',
#  'Kääbik: Viie väe lahing trailer',
#  'Big Hero 6 clips',
#  'Big Hero 6 scene',
#  'Big Hero 6 opening',
#  'Big Hero 6 ending',
#  'Big Hero 6 trailer',
#  'clips',
#  'scene',
#  'opening',
#  'ending',
#  'trailer',
#  'Город героев clips',
#  'Город героев scene',
#  'Город героев opening',
#  'Город героев ending',
#  'Город героев trailer',
#  'Les Nouveaux Héros clips',
#  'Les Nouveaux Héros scene',
#  'Les Nouveaux Héros opening',
#  'Les Nouveaux Héros ending',
#  'Les Nouveaux Héros trailer',
#  'Baymax - Riesiges Robowabohu clips',
#  'Baymax - Riesiges Robowabohu scene',
#  'Baymax - Riesiges Robowabohu opening',
#  'Baymax - Riesiges Robowabohu ending',
#  'Baymax - Riesiges Robowabohu trailer',
#  'Big Hero 6 - Os Novos Heróis clips',
#  'Big Hero 6 - Os Novos Heróis scene',
#  'Big Hero 6 - Os Novos Heróis opening',
#  'Big Hero 6 - Os Novos Heróis ending',
#  'Big Hero 6 - Os Novos Heróis trailer',
#  '6 גיבורים clips',
#  '6 גיבורים scene',
#  '6 גיבורים opening',
#  '6 גיבורים ending',
#  '6 גיבורים trailer',
#  '超能陆战队 clips',
#  '超能陆战队 scene',
#  '超能陆战队 opening',
#  '超能陆战队 ending',
#  '超能陆战队 trailer',
#  'Οι Υπερέξι clips',
#  'Οι Υπερέξι scene',
#  'Οι Υπερέξι opening',
#  'Οι Υπερέξι ending',
#  'Οι Υπερέξι trailer',
#  'Hős 6-os clips',
#  'Hős 6-os scene',
#  'Hős 6-os opening',
#  'Hős 6-os ending',
#  'Hős 6-os trailer',
#  'Velká šestka clips',
#  'Velká šestka scene',
#  'Velká šestka opening',
#  'Velká šestka ending',
#  'Velká šestka trailer',
#  'Героичната шесторка clips',
#  'Героичната шесторка scene',
#  'Героичната шесторка opening',
#  'Героичната шесторка ending',
#  'Героичната шесторка trailer',
#  'Veľká šestka clips',
#  'Veľká šestka scene',
#  'Veľká šestka opening',
#  'Veľká šestka ending',
#  'Veľká šestka trailer',
#  '6 Süper Kahraman clips',
#  '6 Süper Kahraman scene',
#  '6 Süper Kahraman opening',
#  '6 Süper Kahraman ending',
#  '6 Süper Kahraman trailer',
#  'Wielka Szóstka clips',
#  'Wielka Szóstka scene',
#  'Wielka Szóstka opening',
#  'Wielka Szóstka ending',
#  'Wielka Szóstka trailer',
#  'บิ๊กฮีโร่ 6 clips',
#  'บิ๊กฮีโร่ 6 scene',
#  'บิ๊กฮีโร่ 6 opening',
#  'บิ๊กฮีโร่ 6 ending',
#  'บิ๊กฮีโร่ 6 trailer',
#  '빅 히어로 clips',
#  '빅 히어로 scene',
#  '빅 히어로 opening',
#  '빅 히어로 ending',
#  '빅 히어로 trailer',
#  'ベイマックス clips',
#  'ベイマックス scene',
#  'ベイマックス opening',
#  'ベイマックス ending',
#  'ベイマックス trailer',
#  'Veličastnih 6 clips',
#  'Veličastnih 6 scene',
#  'Veličastnih 6 opening',
#  'Veličastnih 6 ending',
#  'Veličastnih 6 trailer',
#  'Супер шістка clips',
#  'Супер шістка scene',
#  'Супер шістка opening',
#  'Супер шістка ending',
#  'Супер шістка trailer',
#  'شش قهرمان بزرگ clips',
#  'شش قهرمان بزرگ scene',
#  'شش قهرمان بزرگ opening',
#  'شش قهرمان بزرگ ending',
#  'شش قهرمان بزرگ trailer',
#  'Cei 6 super eroi clips',
#  'Cei 6 super eroi scene',
#  'Cei 6 super eroi opening',
#  'Cei 6 super eroi ending',
#  'Cei 6 super eroi trailer',
#  'Operação Big Hero clips',
#  'Operação Big Hero scene',
#  'Operação Big Hero opening',
#  'Operação Big Hero ending',
#  'Operação Big Hero trailer',
#  '大英雄天團 clips',
#  '大英雄天團 scene',
#  '大英雄天團 opening',
#  '大英雄天團 ending',
#  '大英雄天團 trailer',
#  'الأبطال الستة clips',
#  'الأبطال الستة scene',
#  'الأبطال الستة opening',
#  'الأبطال الستة ending',
#  'الأبطال الستة trailer',
#  'Grandes héroes clips',
#  'Grandes héroes scene',
#  'Grandes héroes opening',
#  'Grandes héroes ending',
#  'Grandes héroes trailer',
#  '6 Böyük Qehreman clips',
#  '6 Böyük Qehreman scene',
#  '6 Böyük Qehreman opening',
#  '6 Böyük Qehreman ending',
#  '6 Böyük Qehreman trailer',
#  '6 Kangelast clips',
#  '6 Kangelast scene',
#  '6 Kangelast opening',
#  '6 Kangelast ending',
#  '6 Kangelast trailer',
#  'Les nouveaux héros clips',
#  'Les nouveaux héros scene',
#  'Les nouveaux héros opening',
#  'Les nouveaux héros ending',
#  'Les nouveaux héros trailer',
#  'Ekipa za 6 clips',
#  'Ekipa za 6 scene',
#  'Ekipa za 6 opening',
#  'Ekipa za 6 ending',
#  'Ekipa za 6 trailer',
#  'Galingasis 6 clips',
#  'Galingasis 6 scene',
#  'Galingasis 6 opening',
#  'Galingasis 6 ending',
#  'Galingasis 6 trailer',
#  'Lielais 6 clips',
#  'Lielais 6 scene',
#  'Lielais 6 opening',
#  'Lielais 6 ending',
#  'Lielais 6 trailer',
#  'Град хероја clips',
#  'Град хероја scene',
#  'Град хероја opening',
#  'Град хероја ending',
#  'Град хероја trailer',
#  '大英雄聯盟 clips',
#  '大英雄聯盟 scene',
#  '大英雄聯盟 opening',
#  '大英雄聯盟 ending',
#  '大英雄聯盟 trailer',
#  ...]

# %%
len(VIDEO_ID_QUEUE)
# Out:
# 13664

# %%
VIDEO_ID_QUEUE
# Out:
# ['AkcfB3z0_-0',
#  'KIKEHZCL5Nc',
#  '5BxqahE0fu8',
#  'QsvRms3HJi4',
#  'AkcfB3z0_-0',
#  '5BxqahE0fu8',
#  '3MNWGN905Co',
#  'KIKEHZCL5Nc',
#  'NBQJjqnG1iI',
#  '1b2CtgkwJQA',
#  'RUHHxecmLUI',
#  'xFLlrcLbxHU',
#  'BWjxfzFnGRQ',
#  'JXTdArIvggI',
#  'bs1Wkl7m1qs',
#  'EycQn0z61VY',
#  'vIu85WQTPRc',
#  'qqrpMRDuPfc',
#  'wVDtmouV9kM',
#  'QFxN2oDKk0E',
#  'zkpMEzz19RA',
#  'K1htLxKV3bs',
#  'RobDdJNS-Gg',
#  'kfe_pvnFFE0',
#  'AkcfB3z0_-0',
#  'zkpMEzz19RA',
#  'abjCORW2SIo',
#  'ZYwDPnPKLIs',
#  'RobDdJNS-Gg',
#  'GomKKHPKJFA',
#  'cD0FeOrK6rk',
#  'msdFDqV4oi4',
#  '2qquWqyB5LQ',
#  'IIdmPW3Bozs',
#  'm6ng-7OxvNg',
#  'CqwgFgPRQw8',
#  'zkpMEzz19RA',
#  'K1htLxKV3bs',
#  's1DUC_wBUvY',
#  'rG74w_-abrA',
#  'AkcfB3z0_-0',
#  'r_0JjYUe5jo',
#  '42poB7JbV00',
#  'nf7GsKFepDg',
#  'AkcfB3z0_-0',
#  '42poB7JbV00',
#  '5BxqahE0fu8',
#  'XQRDcf6f6Ls',
#  'NBQJjqnG1iI',
#  '1b2CtgkwJQA',
#  'mBlPuHK7W-4',
#  'RUHHxecmLUI',
#  '42poB7JbV00',
#  'BWjxfzFnGRQ',
#  'EycQn0z61VY',
#  'bs1Wkl7m1qs',
#  'vIu85WQTPRc',
#  'qqrpMRDuPfc',
#  'pt6bMHUoE6I',
#  'lV1OOlGwExM',
#  'B0UZs9Gj_Ko',
#  'odM92ap8_c0',
#  'U2pYosKhK6M',
#  'Bwd3Jpxww60',
#  'B0UZs9Gj_Ko',
#  'KIKEHZCL5Nc',
#  'tpfKZXXOQRA',
#  'AkcfB3z0_-0',
#  'odM92ap8_c0',
#  'o6qAIaqK3_Q',
#  'gBguGe-BlNE',
#  'AkcfB3z0_-0',
#  'Bwd3Jpxww60',
#  'odM92ap8_c0',
#  'B0UZs9Gj_Ko',
#  'UGctgnNK5O8',
#  'qqrpMRDuPfc',
#  'lV1OOlGwExM',
#  'odM92ap8_c0',
#  'pt6bMHUoE6I',
#  'r_0JjYUe5jo',
#  'qqrpMRDuPfc',
#  'KIKEHZCL5Nc',
#  'l_skUvZMBys',
#  'KIKEHZCL5Nc',
#  'l_skUvZMBys',
#  'jNVlRoe-iIU',
#  'bL9MQZQPefo',
#  'j2iUQ6sta_c',
#  'iLvJRacXOEQ',
#  'rWLNKDpk1aE',
#  '2HVR5GFQIdM',
#  'qqrpMRDuPfc',
#  'JC-DOCbdbmw',
#  'sd9disIQNCU',
#  'bL9MQZQPefo',
#  'qqrpMRDuPfc',
#  'vIu85WQTPRc',
#  'odM92ap8_c0',
#  'JC-DOCbdbmw',
#  'AkcfB3z0_-0',
#  '42poB7JbV00',
#  '5BxqahE0fu8',
#  'KIKEHZCL5Nc',
#  'AkcfB3z0_-0',
#  '5BxqahE0fu8',
#  'JuEa6Hum0b4',
#  '3MNWGN905Co',
#  'NBQJjqnG1iI',
#  '1b2CtgkwJQA',
#  '6Rt2aydgo2Y',
#  'xFLlrcLbxHU',
#  'BWjxfzFnGRQ',
#  'JXTdArIvggI',
#  'EycQn0z61VY',
#  'b4xgewnNo2E',
#  'qqrpMRDuPfc',
#  'lV1OOlGwExM',
#  'hqFqEQdswfk',
#  'vIu85WQTPRc',
#  'AkcfB3z0_-0',
#  'KIKEHZCL5Nc',
#  '5BxqahE0fu8',
#  'QsvRms3HJi4',
#  'AkcfB3z0_-0',
#  '5BxqahE0fu8',
#  'jmbQmQ17X3E',
#  '3MNWGN905Co',
#  'NBQJjqnG1iI',
#  '1b2CtgkwJQA',
#  'RUHHxecmLUI',
#  'xFLlrcLbxHU',
#  'BWjxfzFnGRQ',
#  'JXTdArIvggI',
#  'bs1Wkl7m1qs',
#  'EycQn0z61VY',
#  'vIu85WQTPRc',
#  'qqrpMRDuPfc',
#  'wVDtmouV9kM',
#  'PG440_H5BLI',
#  'AkcfB3z0_-0',
#  'VV97_cn54bQ',
#  'r_0JjYUe5jo',
#  'n95M4QKuMxo',
#  'AkcfB3z0_-0',
#  '5BxqahE0fu8',
#  'PIjCt8M9XJI',
#  'nglTPbYIhf0',
#  'NBQJjqnG1iI',
#  'UvjDoDYKOno',
#  '1b2CtgkwJQA',
#  'cD0FeOrK6rk',
#  'elPtrNQWdXc',
#  'BWjxfzFnGRQ',
#  '6npU3Fw6bb8',
#  'lGbHN5NjImM',
#  'qqrpMRDuPfc',
#  'lV1OOlGwExM',
#  'vIu85WQTPRc',
#  'odM92ap8_c0',
#  'aHcCCquDyqM',
#  'AkcfB3z0_-0',
#  'V2aJ1WkYvTs',
#  'GuV-Vb1PlSU',
#  'x7ythIm0834',
#  'AkcfB3z0_-0',
#  'uaG2gCHFyKk',
#  'JRSmhoDc5q4',
#  'NBQJjqnG1iI',
#  'mBlPuHK7W-4',
#  '3Mek_jlr_c4',
#  'eXd4ZwDivsc',
#  'MBfEYXwqrnA',
#  'nijVMU8k6hw',
#  'FsG9Y9SxzHY',
#  '-by2BsRzspE',
#  'x7ythIm0834',
#  'a_WRsHyOTjY',
#  'fRc1hIpf80s',
#  'n5PFOjZnStg',
#  'AkcfB3z0_-0',
#  'KIKEHZCL5Nc',
#  'Jel2A5U1msg',
#  'XCpXzhvov7E',
#  'AkcfB3z0_-0',
#  'KIKEHZCL5Nc',
#  'JuEa6Hum0b4',
#  '7c7-cpvi49s',
#  'NBQJjqnG1iI',
#  '1b2CtgkwJQA',
#  'RUHHxecmLUI',
#  'xFLlrcLbxHU',
#  'eaCDO6k7DCY',
#  'bs1Wkl7m1qs',
#  'lOO8Um_jmLI',
#  'UyAdpjZ5zlc',
#  '66JAFm9ujDo',
#  'tV48m43NGOA',
#  'vIu85WQTPRc',
#  'rBqt9WT-ofM',
#  '42poB7JbV00',
#  'AkcfB3z0_-0',
#  'JiPjsRT3Kb4',
#  '4IsISIQpKTc',
#  '42poB7JbV00',
#  'AkcfB3z0_-0',
#  '5BxqahE0fu8',
#  'JiPjsRT3Kb4',
#  'NBQJjqnG1iI',
#  '1b2CtgkwJQA',
#  'RUHHxecmLUI',
#  'xFLlrcLbxHU',
#  '42poB7JbV00',
#  'elPtrNQWdXc',
#  'EycQn0z61VY',
#  'BWjxfzFnGRQ',
#  'qqrpMRDuPfc',
#  'lV1OOlGwExM',
#  'pt6bMHUoE6I',
#  'vIu85WQTPRc',
#  '725M4eHgqo8',
#  'AkcfB3z0_-0',
#  'KIKEHZCL5Nc',
#  'TzTLkyQ-yjo',
#  'AkcfB3z0_-0',
#  'JuEa6Hum0b4',
#  'abjCORW2SIo',
#  'KIKEHZCL5Nc',
#  'NBQJjqnG1iI',
#  '1b2CtgkwJQA',
#  'xFLlrcLbxHU',
#  'D-vR_jfQgF0',
#  'EycQn0z61VY',
#  'G0hfmLWi2-M',
#  'bs1Wkl7m1qs',
#  'LqCESPAqymg',
#  'zkpMEzz19RA',
#  'rG74w_-abrA',
#  '79yugOtwTX8',
#  's1DUC_wBUvY',
#  'MnBI139TpiI',
#  'c6s73Ab8A6g',
#  'AkcfB3z0_-0',
#  'xnidVEITXgQ',
#  'MnBI139TpiI',
#  'QsvRms3HJi4',
#  'AkcfB3z0_-0',
#  'c6s73Ab8A6g',
#  'NBQJjqnG1iI',
#  'cD0FeOrK6rk',
#  '2HVR5GFQIdM',
#  'j2iUQ6sta_c',
#  'qqrpMRDuPfc',
#  'BWjxfzFnGRQ',
#  'a97jXvcPHbU',
#  '3MNWGN905Co',
#  '3WJLW831ETI',
#  'uQcxSILZ8o8',
#  'odM92ap8_c0',
#  'QFxN2oDKk0E',
#  'qdg6UaTtivo',
#  'hcf7g7PzXx8',
#  'jmbQmQ17X3E',
#  'l58mxmKvUFw',
#  'AkcfB3z0_-0',
#  'PxsDTbClCV8',
#  'l_skUvZMBys',
#  '1ZMKMoPpVAo',
#  '1b2CtgkwJQA',
#  'NBQJjqnG1iI',
#  'xFLlrcLbxHU',
#  'rWLNKDpk1aE',
#  'XJfm_0Gc7Fc',
#  'b4xgewnNo2E',
#  'EycQn0z61VY',
#  'bs1Wkl7m1qs',
#  'vIu85WQTPRc',
#  'odM92ap8_c0',
#  'pt6bMHUoE6I',
#  'wVDtmouV9kM',
#  'AkcfB3z0_-0',
#  'KIKEHZCL5Nc',
#  'r_0JjYUe5jo',
#  'fFYP8O-YwpE',
#  'AkcfB3z0_-0',
#  'PxsDTbClCV8',
#  'BsHgi9wvVys',
#  'yF1SOR-VInU',
#  'AkcfB3z0_-0',
#  '83ki24Ep4HI',
#  'cZFnRQ787bc',
#  'iLvJRacXOEQ',
#  '83ki24Ep4HI',
#  '5BxqahE0fu8',
#  'cZFnRQ787bc',
#  'qqrpMRDuPfc',
#  'vIu85WQTPRc',
#  'odM92ap8_c0',
#  'QFxN2oDKk0E',
#  'pt6bMHUoE6I',
#  'OA3Txp94pjs',
#  'DB8i1kyXkWc',
#  's_M1t0HE-Kk',
#  'sBNzE1mmbs4',
#  's_M1t0HE-Kk',
#  'Rvns5DaW-ug',
#  'DB8i1kyXkWc',
#  'a3lcGnMhvsA',
#  'l5NPGC0jlRc',
#  'bmz9lMP6aQU',
#  'UDVtMYqUAyw',
#  'MJ9v-0jC4lQ',
#  'ECjYsWLgy3I',
#  '7A3rreNFr3w',
#  '8LiVGDq01FU',
#  'j3DuONZb3Ik',
#  '2LqzF5WauAw',
#  'zSWdZVtXT7E',
#  'nyc6RJEEe0U',
#  '6W6XMvYH0Xs',
#  'J-Yjyr6OM4Y',
#  'K1R4hHq8yr4',
#  'TuRAy_ihjM0',
#  '-byocJxvphc',
#  'DhAEy2gRDIM',
#  'EaGuorNPJZM',
#  'MSCopoYEnKg',
#  'tbVGLdQJY-s',
#  '9rVKos-oGnQ',
#  'IrM-f1mTJrs',
#  'CID-sYQNCew',
#  'DZE8I-ItixU',
#  'TOIF7KwXetU',
#  'hiVJoS0zwu0',
#  'EoVQ_TQFJy0',
#  'B3Z4XGAxJB0',
#  'MjQG-a7d41Q',
#  'cen0rBKLuYE',
#  'BZTI5OWypAg',
#  'K_DSF87l8C8',
#  'a3lcGnMhvsA',
#  '8kooIgKESYE',
#  'onVhbeY7nLM',
#  '70gm16sUA1A',
#  'a3lcGnMhvsA',
#  'jjOhnn_wHSA',
#  'onVhbeY7nLM',
#  'c4tPQYNpW9k',
#  'UDVtMYqUAyw',
#  'yBs3vSUflps',
#  '8kooIgKESYE',
#  'EGcXF0iG-2s',
#  'jjOhnn_wHSA',
#  'c4tPQYNpW9k',
#  's_M1t0HE-Kk',
#  'UDVtMYqUAyw',
#  'u9GEcdg5QKc',
#  'mXQg38y8gRU',
#  'EpUpK62PPR0',
#  'H3bUzVt37vA',
#  '8kooIgKESYE',
#  'onVhbeY7nLM',
#  'cU0Wz1ez3J0',
#  'HTvJl71zmf4',
#  'a3lcGnMhvsA',
#  'onVhbeY7nLM',
#  'DB8i1kyXkWc',
#  'OA3Txp94pjs',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'onVhbeY7nLM',
#  'l5NPGC0jlRc',
#  'ECjYsWLgy3I',
#  '7A3rreNFr3w',
#  'I8oXl1_QnLA',
#  'sf9mGrl4PJM',
#  'qcPfI0y7wRU',
#  'zSWdZVtXT7E',
#  'm2vijtILDuk',
#  '6W6XMvYH0Xs',
#  'aN53Va60sY8',
#  'HTvJl71zmf4',
#  'cU0Wz1ez3J0',
#  'onVhbeY7nLM',
#  'QIumIjSpC3Q',
#  'aN53Va60sY8',
#  'eu9U8_H9kRk',
#  'OA3Txp94pjs',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'onVhbeY7nLM',
#  'THhjjnsgFlE',
#  'eu9U8_H9kRk',
#  '1tVbQEzxEDg',
#  '3v9OhgS99t8',
#  'nBOdJ6xSDu0',
#  'g0mWHu0KAJA',
#  'dWrXp_O-dWo',
#  '4T4wxDnTYLg',
#  '3SHS0fQ3yL4',
#  'IIkP10vwxV8',
#  '-FGVJS3rT80',
#  'cU0Wz1ez3J0',
#  '8kooIgKESYE',
#  'nX6kgKtjSoA',
#  '8kooIgKESYE',
#  'QPuC7q-GYOc',
#  '4GkAAmk_nf8',
#  'IIkP10vwxV8',
#  'rpPk6Y3vth4',
#  'vN__D2o8kxQ',
#  'PWmF4WFNHho',
#  'sf9mGrl4PJM',
#  '49ySd8YKlc4',
#  'I8oXl1_QnLA',
#  'pXotJu1CapU',
#  'LY19rHKAaAg',
#  'GBHAHnOBFhw',
#  'IIkP10vwxV8',
#  'c3NY0OZ2p04',
#  '8kooIgKESYE',
#  'ECjYsWLgy3I',
#  '4GkAAmk_nf8',
#  'HTvJl71zmf4',
#  'ECjYsWLgy3I',
#  '8kooIgKESYE',
#  'c4tPQYNpW9k',
#  'HTvJl71zmf4',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'YF1eYbfbH5k',
#  'kpz8lpoLvrA',
#  'ECjYsWLgy3I',
#  'sf9mGrl4PJM',
#  'pH1vWZJWlsQ',
#  '7JE9sEEb_HE',
#  'zSWdZVtXT7E',
#  'RB_unzL3l_Y',
#  '6W6XMvYH0Xs',
#  'Sxrk75UcwZI',
#  '8kooIgKESYE',
#  'HTvJl71zmf4',
#  'cU0Wz1ez3J0',
#  'a3lcGnMhvsA',
#  'a3lcGnMhvsA',
#  'c4tPQYNpW9k',
#  '0pT6tJnsVhE',
#  'cU0Wz1ez3J0',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'YF1eYbfbH5k',
#  'kpz8lpoLvrA',
#  'sf9mGrl4PJM',
#  'OA3Txp94pjs',
#  'cU0Wz1ez3J0',
#  'UDVtMYqUAyw',
#  'RB_unzL3l_Y',
#  '6W6XMvYH0Xs',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'OA3Txp94pjs',
#  '8kooIgKESYE',
#  'HTvJl71zmf4',
#  'cU0Wz1ez3J0',
#  'onVhbeY7nLM',
#  'a3lcGnMhvsA',
#  'Rvns5DaW-ug',
#  's_M1t0HE-Kk',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'kpz8lpoLvrA',
#  'kottjfEd7Zw',
#  'ECjYsWLgy3I',
#  'j3DuONZb3Ik',
#  '7A3rreNFr3w',
#  '8LiVGDq01FU',
#  'vVJeYMRam0o',
#  'zSWdZVtXT7E',
#  'HfuDh4yNFGY',
#  '4GkAAmk_nf8',
#  'DB8i1kyXkWc',
#  '-FGVJS3rT80',
#  'cU0Wz1ez3J0',
#  'GIUhpzv47YQ',
#  'onVhbeY7nLM',
#  'DbOFNT6B5Pk',
#  'Rvns5DaW-ug',
#  'v2H1s9gj5DA',
#  'l5NPGC0jlRc',
#  'HV0JZaVO01I',
#  'UBQH6EJOSL4',
#  'YF1eYbfbH5k',
#  'h2kaG0AstXs',
#  'LmWjZCSBnAc',
#  'K7DZIVe7Aj8',
#  'FG_dcCOR10E',
#  'd2VN6NNa9BE',
#  '66_Iosx46DI',
#  'vABfjuXZhYY',
#  'BAzCf0ascW8',
#  'Ib85_TS6uck',
#  'F6aIiijduXk',
#  '0FlVw5PGIBM',
#  'cU0Wz1ez3J0',
#  '0FlVw5PGIBM',
#  'Ib85_TS6uck',
#  'F6aIiijduXk',
#  'JqKa6qyVYgg',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'YF1eYbfbH5k',
#  '4y33h81phKU',
#  'QTf3H9WVMIw',
#  '0Ima1bX6RLI',
#  '7A3rreNFr3w',
#  'OQMVYs0JwQI',
#  'isoTSzwBMKE',
#  'f7R5PtXCZU8',
#  'sSgvsLyi6_o',
#  'iBfk37Fa3H0',
#  '8kooIgKESYE',
#  '6u7f1ODt-eE',
#  'QkeS11nVl-Q',
#  'sBNzE1mmbs4',
#  'Rvns5DaW-ug',
#  '_GdEsdEfZvc',
#  'a3lcGnMhvsA',
#  'PeUeQRmjE3s',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'YF1eYbfbH5k',
#  'THhjjnsgFlE',
#  'j3DuONZb3Ik',
#  '7A3rreNFr3w',
#  'sf9mGrl4PJM',
#  'ECjYsWLgy3I',
#  '2LqzF5WauAw',
#  'Lm8p5rlrSkY',
#  '6W6XMvYH0Xs',
#  'nyc6RJEEe0U',
#  'm3yOTsB88gc',
#  '665o5OwV_KU',
#  'HTvJl71zmf4',
#  'sUmoMSU9_GQ',
#  'ZFjDmokHAiM',
#  't459y7baQmA',
#  'nX6kgKtjSoA',
#  '665o5OwV_KU',
#  'ZFjDmokHAiM',
#  'UDVtMYqUAyw',
#  'THhjjnsgFlE',
#  'cU0Wz1ez3J0',
#  'cXnQx13eEgc',
#  'I8oXl1_QnLA',
#  'sf9mGrl4PJM',
#  'txDfjCSYXQs',
#  'TncKujrUJ-g',
#  'ZFjDmokHAiM',
#  'zcZcRTvyVL0',
#  'MECIbKh3g5w',
#  'AHkVrOXC0sg',
#  'MGPM58S5Njg',
#  'jf_4z4AKwJg',
#  'OLHYwFpfNoE',
#  'bknRZaYsjc4',
#  '7zHvdxeEnsk',
#  'q2bW4u63WcU',
#  'xhEIQVmjV38',
#  'VW3tfoay2M0',
#  'MngKpBKw3Xg',
#  'MGPM58S5Njg',
#  '9hdp9LL59sw',
#  '1ZS3Of2Rz6k',
#  'VmBnRUfP9Aw',
#  'tzg3LYi5Oyw',
#  'OLHYwFpfNoE',
#  'VmBnRUfP9Aw',
#  '1ZS3Of2Rz6k',
#  'nZbD0n5H-Xg',
#  'MGPM58S5Njg',
#  'tchCQYm77tY',
#  'hxAMhvqyHks',
#  'hB2pXI6atHs',
#  'Qx3N5K1WvsQ',
#  'tchCQYm77tY',
#  '1RCvPNtS2jw',
#  'zIkq3_IcpHs',
#  '0u3IZl4lBcQ',
#  'YF1eYbfbH5k',
#  'X295dXspL3Y',
#  'XtPZ8-fjTGQ',
#  'zSWdZVtXT7E',
#  'tchCQYm77tY',
#  'hxAMhvqyHks',
#  '1RCvPNtS2jw',
#  'TWhB9tvPZGE',
#  's6o8hQacWBs',
#  'tchCQYm77tY',
#  'oqTJKtUjnFU',
#  'hB2pXI6atHs',
#  'KXXHx4BzJB0',
#  'nX6kgKtjSoA',
#  'JqFW1rBqzzQ',
#  '0M3fP2MRtp4',
#  '4GkAAmk_nf8',
#  'nX6kgKtjSoA',
#  '-FGVJS3rT80',
#  '8kooIgKESYE',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'THhjjnsgFlE',
#  'kpz8lpoLvrA',
#  'pAbWzZV5n-g',
#  'sf9mGrl4PJM',
#  'I8oXl1_QnLA',
#  'fczY_FCOLME',
#  '2LqzF5WauAw',
#  '4GkAAmk_nf8',
#  '665o5OwV_KU',
#  '8kooIgKESYE',
#  'tzLf1pmBf4k',
#  '8kooIgKESYE',
#  'NBy5Qk89JLA',
#  'DB8i1kyXkWc',
#  '4_MHumAFa6o',
#  'drvGjGzYWkw',
#  'DB8i1kyXkWc',
#  'lvhks1XIXTw',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'YF1eYbfbH5k',
#  'kpz8lpoLvrA',
#  'OcEFoc6HE4k',
#  'iEJjYaYg0Jc',
#  'nUBsmcFaUuk',
#  '4_MHumAFa6o',
#  'v7FQ8PZNH6E',
#  'LY19rHKAaAg',
#  'nyc6RJEEe0U',
#  'RB_unzL3l_Y',
#  'HTvJl71zmf4',
#  'LWkwqrI8TeA',
#  'Qo7DfB-mj98',
#  'wMoLd7YoBQ4',
#  'QIumIjSpC3Q',
#  'cU0Wz1ez3J0',
#  'wMoLd7YoBQ4',
#  'LWkwqrI8TeA',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'YF1eYbfbH5k',
#  '4y33h81phKU',
#  'eu9U8_H9kRk',
#  '3v9OhgS99t8',
#  '1tVbQEzxEDg',
#  'uXFf3RVj9GY',
#  'g0mWHu0KAJA',
#  'dWrXp_O-dWo',
#  '3SHS0fQ3yL4',
#  'J7Ovq7M3EPU',
#  'OA3Txp94pjs',
#  'DB8i1kyXkWc',
#  's_M1t0HE-Kk',
#  'sBNzE1mmbs4',
#  's_M1t0HE-Kk',
#  'DB8i1kyXkWc',
#  'a3lcGnMhvsA',
#  'onVhbeY7nLM',
#  'l5NPGC0jlRc',
#  'bmz9lMP6aQU',
#  'MJ9v-0jC4lQ',
#  'UBQH6EJOSL4',
#  'ECjYsWLgy3I',
#  '7A3rreNFr3w',
#  '8LiVGDq01FU',
#  'j3DuONZb3Ik',
#  'zSWdZVtXT7E',
#  '2LqzF5WauAw',
#  'hHBsKHVLAYc',
#  'UoSSbmD9vqc',
#  'HTvJl71zmf4',
#  '8kooIgKESYE',
#  'cU0Wz1ez3J0',
#  '4GkAAmk_nf8',
#  'QlXTIvWXDLU',
#  'JqBo1KG7ECk',
#  '0FBiyFpV__g',
#  'y0jZ3HCEc-Q',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'THhjjnsgFlE',
#  'cU0Wz1ez3J0',
#  'sf9mGrl4PJM',
#  'fczY_FCOLME',
#  'txDfjCSYXQs',
#  'pH1vWZJWlsQ',
#  'jcEY-fkNI7Y',
#  '8kooIgKESYE',
#  'DwoqmbpV4-g',
#  'b6rs1gdkJoM',
#  'HTvJl71zmf4',
#  '8kooIgKESYE',
#  '4GkAAmk_nf8',
#  'a3lcGnMhvsA',
#  's_M1t0HE-Kk',
#  'DB8i1kyXkWc',
#  'a3lcGnMhvsA',
#  'onVhbeY7nLM',
#  'UDVtMYqUAyw',
#  'zRVaX8mreEs',
#  'YF1eYbfbH5k',
#  '8kooIgKESYE',
#  'ECjYsWLgy3I',
#  '7A3rreNFr3w',
#  '8LiVGDq01FU',
#  'j3DuONZb3Ik',
#  '2LqzF5WauAw',
#  'zSWdZVtXT7E',
#  'nyc6RJEEe0U',
#  'Lm8p5rlrSkY',
#  'HTvJl71zmf4',
#  '-FGVJS3rT80',
#  '8kooIgKESYE',
#  '665o5OwV_KU',
#  'nX6kgKtjSoA',
#  '8kooIgKESYE',
#  '665o5OwV_KU',
#  'd_eGWZG_hgk',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'OlZTCXZbWB0',
#  'TzxK9KOUAEE',
#  'pH1vWZJWlsQ',
#  '49ySd8YKlc4',
#  'sf9mGrl4PJM',
#  'txDfjCSYXQs',
#  'zSWdZVtXT7E',
#  '2LqzF5WauAw',
#  '3WzHXI5HizQ',
#  '8kooIgKESYE',
#  '-FGVJS3rT80',
#  '665o5OwV_KU',
#  'cU0Wz1ez3J0',
#  '8kooIgKESYE',
#  'c4tPQYNpW9k',
#  'jP_RRMi_4Ts',
#  '05vb8HfN7TM',
#  'PeUeQRmjE3s',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'cU0Wz1ez3J0',
#  'cArIrYgIcmI',
#  'mkFGVy2tBsk',
#  'fczY_FCOLME',
#  'I8oXl1_QnLA',
#  'sf9mGrl4PJM',
#  '4T4wxDnTYLg',
#  'zSWdZVtXT7E',
#  'nXexUpD2q1s',
#  'LY19rHKAaAg',
#  'YUlcU5wCtGs',
#  'QqSp_dwslro',
#  'rl4-SDcMPuE',
#  '2ga5T84fQ-s',
#  'rl4-SDcMPuE',
#  'GlsVao6D2gw',
#  'QqSp_dwslro',
#  '8qGF1fOfRYI',
#  'YUlcU5wCtGs',
#  'UDVtMYqUAyw',
#  'QqSp_dwslro',
#  'rl4-SDcMPuE',
#  'rl4-SDcMPuE',
#  '01tLCwMbrJg',
#  '6tWi3c4tfjk',
#  'sf9mGrl4PJM',
#  'QqSp_dwslro',
#  '4RCzymlJ-fc',
#  'YUlcU5wCtGs',
#  'lA6u1chIrtw',
#  '8kooIgKESYE',
#  '665o5OwV_KU',
#  'cU0Wz1ez3J0',
#  '-FGVJS3rT80',
#  '665o5OwV_KU',
#  '8kooIgKESYE',
#  '4GkAAmk_nf8',
#  'nX6kgKtjSoA',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'THhjjnsgFlE',
#  'ucq1sLjLVSA',
#  'sf9mGrl4PJM',
#  'fczY_FCOLME',
#  'UDVtMYqUAyw',
#  'oWfHMl1YTJc',
#  'jcEY-fkNI7Y',
#  'E5tRsg6geBA',
#  'SQaOt0PoXLQ',
#  'b_VGPZH8zlY',
#  '-FGVJS3rT80',
#  'onVhbeY7nLM',
#  '69EUgdj7lzI',
#  'DB8i1kyXkWc',
#  'onVhbeY7nLM',
#  'a3lcGnMhvsA',
#  '8kooIgKESYE',
#  'v2H1s9gj5DA',
#  'l5NPGC0jlRc',
#  '8kooIgKESYE',
#  'YF1eYbfbH5k',
#  'UBQH6EJOSL4',
#  'eu9U8_H9kRk',
#  '7A3rreNFr3w',
#  '8LiVGDq01FU',
#  'j3DuONZb3Ik',
#  'g0mWHu0KAJA',
#  '2LqzF5WauAw',
#  '6W6XMvYH0Xs',
#  'zSWdZVtXT7E',
#  'c4tPQYNpW9k',
#  'HTvJl71zmf4',
#  'cU0Wz1ez3J0',
#  '-FGVJS3rT80',
#  'c4tPQYNpW9k',
#  '8kooIgKESYE',
#  'jP_RRMi_4Ts',
#  'nX6kgKtjSoA',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'EGcXF0iG-2s',
#  'THhjjnsgFlE',
#  'sf9mGrl4PJM',
#  'fczY_FCOLME',
#  'c4tPQYNpW9k',
#  '7JE9sEEb_HE',
#  'zSWdZVtXT7E',
#  'OG8Vt9eoBxA',
#  'LLKAdslwzBo',
#  'DwoqmbpV4-g',
#  '665o5OwV_KU',
#  '-FGVJS3rT80',
#  'cU0Wz1ez3J0',
#  '4GkAAmk_nf8',
#  'nX6kgKtjSoA',
#  '8kooIgKESYE',
#  '4GkAAmk_nf8',
#  '05vb8HfN7TM',
#  'UDVtMYqUAyw',
#  '8kooIgKESYE',
#  'kpz8lpoLvrA',
#  'THhjjnsgFlE',
#  'pH1vWZJWlsQ',
#  'sf9mGrl4PJM',
#  'I8oXl1_QnLA',
#  'dUriakRAD_w',
#  'jcEY-fkNI7Y',
#  'Kbi6b4utSPk',
#  'DMZ4HTpyDgw',
#  'XN8N-5MAIUU',
#  'HbIFTmweL-w',
#  't2neTz2x2NE',
#  'tG8FMBMoLws',
#  'pNI__QsaMbw',
#  'v577QHLvM9s',
#  'MTxnFyQ6FZ4',
#  'pNI__QsaMbw',
#  'P7FPH52_uE0',
#  'QgHATo0d3YA',
#  'P7FPH52_uE0',
#  '9vHuQRbQ310',
#  'BP_zvxCurzY',
#  'WlliWLb3N2A',
#  'cih0Ru_xNVU',
#  'BP_zvxCurzY',
#  'xCmCwB-JTPM',
#  'DpSaTrW4leg',
#  '3sHMCRaS3ao',
#  'h_9-3Fj3ZdI',
#  'XtFI7SNtVpY',
#  'qPbUg4MdtB0',
#  'K1R4hHq8yr4',
#  'TuRAy_ihjM0',
#  '-byocJxvphc',
#  'DhAEy2gRDIM',
#  'dtD3FVJ37Rk',
#  '3MjxoaynCmk',
#  'tbVGLdQJY-s',
#  '9rVKos-oGnQ',
#  'CID-sYQNCew',
#  'TemLSMDKSMw',
#  'BylkQHFemTw',
#  'TOIF7KwXetU',
#  'hiVJoS0zwu0',
#  'EoVQ_TQFJy0',
#  'B3Z4XGAxJB0',
#  'MjQG-a7d41Q',
#  'cen0rBKLuYE',
#  'mp1Pax-QHlA',
#  'hJiPAJKjUVg',
#  '-IZEYOVrh-4',
#  'HYj2p6TvVyo',
#  '53qI4Y7Wzmw',
#  'pR9hIrCZbxQ',
#  'HYj2p6TvVyo',
#  '2hS3npFr7aE',
#  '0SdiUIBHxpc',
#  'KDlyi24LL4w',
#  'KDlyi24LL4w',
#  'XtFI7SNtVpY',
#  '-IZEYOVrh-4',
#  '2hS3npFr7aE',
#  '8QQIATPbkX8',
#  'YwKGSbINeMU',
#  'JOnkCjT6Bqo',
#  'KDlyi24LL4w',
#  'KDlyi24LL4w',
#  'o2NdBl9o5CY',
#  'c06wJbX4450',
#  'DpSaTrW4leg',
#  'g0sJBWkdfKI',
#  'SND3gAQUHvk',
#  'O9EokCI8LdI',
#  'AoYAKgjlukU',
#  'g0sJBWkdfKI',
#  'SND3gAQUHvk',
#  'AoYAKgjlukU',
#  'O9EokCI8LdI',
#  'dPcwB7okdzU',
#  'g0sJBWkdfKI',
#  'O9EokCI8LdI',
#  '0oToY2qNzdM',
#  'ZNLFpIjYm4o',
#  'CnO2Um4YxYs',
#  '9cra6yWnJhI',
#  'MmFiY1iUdGQ',
#  'dPcwB7okdzU',
#  't1rnkXViIbM',
#  'Iy6yXiYMEO0',
#  'ZNLFpIjYm4o',
#  'sddCOcAaZrs',
#  '-wSbloQPJh8',
#  'XtFI7SNtVpY',
#  '9cra6yWnJhI',
#  '_kz6s5Yi5Ns',
#  '9cra6yWnJhI',
#  'XtFI7SNtVpY',
#  '1aD5tbtMgPI',
#  'Msv59gwSRek',
#  'XtFI7SNtVpY',
#  'jZ7YHEaGx6U',
#  'aubW6v6-dAE',
#  'JOnkCjT6Bqo',
#  '1aD5tbtMgPI',
#  'C57OGfDEExk',
#  '9cra6yWnJhI',
#  'V0-cW5Woo6Y',
#  'eUkpGTTDQKA',
#  'XtFI7SNtVpY',
#  '0VOSWTF6_LY',
#  'A7Q_ILn8IC4',
#  'TArlsi9mxEo',
#  'BkFUsfS4Hec',
#  'nNLqAqRP1hI',
#  'BkFUsfS4Hec',
#  'A7Q_ILn8IC4',
#  'TArlsi9mxEo',
#  'Y5kqs9t0HH0',
#  'RFRPr7tljTQ',
#  'nNLqAqRP1hI',
#  'BkFUsfS4Hec',
#  'A7Q_ILn8IC4',
#  '1nGx_r-6Zrs',
#  '42jmaYENZ1M',
#  'qexHtbp3Kvs',
#  'krFfp1XzgQM',
#  'nNLqAqRP1hI',
#  'Pnps3h2azi0',
#  'Y6Fr0MSMTXo',
#  'YCh2BaEt19w',
#  'Lah_XGRSNXI',
#  'HQZuLo80sFQ',
#  'n-ANrXYx-tY',
#  'CpXgvDp4EG0',
#  'pqEVzvkqRiE',
#  'PU5JjjuYCPg',
#  'bVeDNI3TqgA',
#  'Ypt0Sl1akIo',
#  'Lah_XGRSNXI',
#  'HQZuLo80sFQ',
#  'bVeDNI3TqgA',
#  'ATGUuLNRqtI',
#  'iXsuPmjlp8U',
#  'xV5Tg_9Fjc4',
#  's1TCO9Gv-dY',
#  'OQzeQCMOPXE',
#  'Lah_XGRSNXI',
#  'HQZuLo80sFQ',
#  'bVeDNI3TqgA',
#  'ATGUuLNRqtI',
#  ...]

# %%
print(len(search_queries) * 4)
print(len(VIDEO_ID_QUEUE))
# Out:
# 13752
# 17076

# %%
RESULTS_LIMIT = 5

VS = VideoSheet(VIDEO_SHEET_ID)
QS = QuerySheet(QUERY_SHEET_ID)

VIDEO_ID_QUEUE = []

search_queries = QS.get_new_queries()

for query in search_queries:
    VIDEO_ID_QUEUE += get_youtube_data(query, results_limit = 5)

NEW_VIDEOS_DF = pd.DataFrame(columns = ['VIDEO ID', 'Name', 'Video Link', 'Resolution', 'Duration', 'Language'])

# %%
# %%capture

for i in range(len(VIDEO_ID_QUEUE)):
    id = VIDEO_ID_QUEUE[i]
    url = "https://www.youtube.com/watch?v=" + id

    download_video(url, id, VIDEO_OUTPUT_PATH)

    record = produce_video_record(url)
    NEW_VIDEOS_DF.loc[-1] = record  # adding a row
    NEW_VIDEOS_DF.index = NEW_VIDEOS_DF.index + 1  # shifting index
    NEW_VIDEOS_DF = NEW_VIDEOS_DF.sort_index()  # sorting by index

    # mark query sheet for every 5 videos

    if (i%5 == 4):
      query = search_queries[int(i/5)]
      QS.mark_query_processed(query)
      QS.update_sheet()

    if (i%11 == 10):
      VS.add_video_data(NEW_VIDEOS_DF)


VS.add_video_data(NEW_VIDEOS_DF)

# for id in VIDEO_ID_QUEUE:

#     url = "https://www.youtube.com/watch?v=" + id

#     download_video(url, id, VIDEO_OUTPUT_PATH)
#     # mark on query sheet here

#     record = produce_video_record(url)
#     NEW_VIDEOS_DF.loc[-1] = record  # adding a row
#     NEW_VIDEOS_DF.index = NEW_VIDEOS_DF.index + 1  # shifting index
#     NEW_VIDEOS_DF = NEW_VIDEOS_DF.sort_index()  # sorting by index

# for query in search_queries:
#     QS.mark_query_processed(query)

# VS.add_video_data(NEW_VIDEOS_DF)
# QS.update_sheet()
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# <ipython-input-10-6488f4933e5e> in <cell line: 1>()
#      18
#      19     if (i%11 == 10):
# ---> 20       VS.add_video_data(NEW_VIDEOS_DF)
#      21
#      22
#
# <ipython-input-4-ee9887643699> in add_video_data(self, df)
#      64         data = df.values.tolist()
#      65     # Update worksheet starting from the next empty row
# ---> 66     self.worksheet.update(f'A{next_row}', data)
#      67
#      68   def update_sheet(self):
#
# /usr/local/lib/python3.10/dist-packages/gspread/utils.py in wrapper(*args, **kwargs)
#     557                 kwargs.setdefault(k, v)
#     558
# --> 559             return f(*args, **kwargs)
#     560         return wrapper
#     561     return decorate
#
# /usr/local/lib/python3.10/dist-packages/gspread/models.py in update(self, range_name, values, **kwargs)
#    1120         })
#    1121
# -> 1122         response = self.spreadsheet.values_update(
#    1123             range_name,
#    1124             params=params,
#
# /usr/local/lib/python3.10/dist-packages/gspread/models.py in values_update(self, range, params, body)
#     239         """
#     240         url = SPREADSHEET_VALUES_URL % (self.id, quote(range))
# --> 241         r = self.client.request('put', url, params=params, json=body)
#     242         return r.json()
#     243
#
# /usr/local/lib/python3.10/dist-packages/gspread/client.py in request(self, method, endpoint, params, data, json, files, headers)
#      71             return response
#      72         else:
# ---> 73             raise APIError(response)
#      74
#      75     def list_spreadsheet_files(self, title=None):
#
# APIError: {'code': 400, 'message': 'Range (Sheet1!A20333) exceeds grid limits. Max rows: 20332, max columns: 29', 'status': 'INVALID_ARGUMENT'}

# %%
while True:pass

# %%
int(6/5)
# Out:
# 1
